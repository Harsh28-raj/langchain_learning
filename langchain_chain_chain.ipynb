# %% [markdown]
# <a href="https://colab.research.google.com/github/Harsh28-raj/langchain_learning/blob/main/langchain_chain_chain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

class NakliLLM:

  def __init__(self):
    print('LLM created')

  def predict(self,prompt):

    response_list = [
        "Delhi is the capital of india",
        "ipl is a cricket league",
        "AI stands for artificial intelligence"
    ]

    return {'response': random.choice(response_list)}

# %%
llm = NakliLLM()
# Out:
# LLM created

# %%
llm.predict('what is the capital of india')
# Out:
# {'response': 'Delhi is the capital of india'}

# %%
class NakliLLMPromptTemplate:

  def __init__(self,template,input_variables):
    self.template = template
    self.input_variables = input_variables

  def fromat(self,input_dict):
    return self.template.format(**input_dict)

# %%
template = NakliLLMPromptTemplate(
    template='Write a {length} poem about {topic}',
    input_variables=['length','topic']
)

# %%
prompt = template.fromat({'length':'short','topic':'india'})

# %%
llm = NakliLLM()
# Out:
# LLM created

# %%
llm.predict(prompt)
# Out:
# {'response': 'ipl is a cricket league'}

# %%
class NakliLLMChain:

  def __init__(self, llm,prompt):
    self.llm = llm
    self.prompt = prompt

  def run(self,input_dict):

    final_prompt = self.prompt.format(input_dict)
    result = self.llm.predict(final_prompt)

    return result['response']

# %%
template = NakliLLMPromptTemplate(
    template='Write a {length} poem about {topic}',
    input_variables=['length','topic']
)

# %%
llm = NakliLLM()
# Out:
# LLM created

# %%
chain = NakliLLMChain(llm,template)

# %%
chain.run({'length':'short','topic':'india'})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_9259/2812062583.py in <cell line: 0>()
# ----> 1 chain.run({'length':'short','topic':'india'})
#
# /tmp/ipykernel_9259/1000091244.py in run(self, input_dict)
#       7   def run(self,input_dict):
#       8
# ----> 9     final_prompt = self.prompt.format(input_dict)
#      10     result = self.llm.predict(final_prompt)
#      11
#
# AttributeError: 'NakliLLMPromptTemplate' object has no attribute 'format'
